# %% [markdown]
# <a href="https://colab.research.google.com/github/owaizkhan117/DS-Lab-Programs/blob/main/Week-6/23_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
X=np.array([1,2,3,4,5,6,7]).reshape(-1,1)
Y=np.array([45,50,65,70,85,90,100])
model=LinearRegression()
model.fit(X,Y)
predictions=model.predict(X)
print("Slope:",model.coef_)
print("Intercept:",model.intercept_)
plt.scatter(X,Y)
plt.plot(X,predictions)
plt.xlabel("Experience")
plt.ylabel("Salary")
plt.title("Salary vs Experience")
plt.show()
# Out:
# Slope: [9.46428571]
# Intercept: 34.285714285714285
